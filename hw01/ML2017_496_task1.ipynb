# %% [markdown]
# <span style="font-size: 14pt">Домашнее задание №1 </span>
#
# <span style="color: red; font-size: 14pt">Deadline: 25.02.2017 23:59:59</span>
#
# <span style="font-size: 10pt">ФИВТ, АПТ, Курс по машинному обучению, Весна 2017, семинар 2, </span>
#
# <span style="color:blue; font-size: 10pt">Alexey Romanenko, </span>
# <span style="color:blue; font-size: 10pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Воронцов К. В. Математические методы обучения по прецедентам. 2012.
# - Мерков А. Б. Распознавание образов. Введение в методы статистического обучения. Едиториал УРСС. 2011. 256 стр.
# - Hastie T., Tibshirani R., Friedman J. The Elements of Statistical Learning. Springer: Data Mining, Inference, and Prediction. — 2nd ed. — Springer-Verlag. 2009. — 746 p.
# - C. M. Bishop. Pattern Recognition and Machine Learning. — Springer, Series: Information Science and Statistics. 2006. — 738 p.
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_fall 496 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер задания>.ipnb``, к примеру -- ``ML2017_496_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2016_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Используются автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Дедлайны жесткие, так что письма пришедшие после автоматически удаляются =( чтобы соблазна не было

# %% [markdown]
# <h1 align="center">Check Questions (0.5 балла) </h1>

# %% [markdown]
# xОтвете на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: Объясните, чем отличается k-nearrest Neighbours от k-weighted nearest neighbours.
#
# В основе алгоритма k-nearrest Neighbours голосование за метку объекта производится простым подсчетом кол-ва классов Y из k ближайших соседей (Т.е. чем больше объектов с меткой класса Y входит в k соседей, тем больше шанс, что наш объект получит метку Y)
#
# В k-weighted nearest neighbours производится взвешанное голосование, помимо кол-ва учитывается расстояние, чем дальше от нашего объекта находится "класс" с меткой Y тем меньше у него голос.
#
# $$votes\,(class) = \sum\limits_{i=1}^{n}\frac{1}{d^2\,(X,\,Y_i )}$$
#
# **Вопрос 2**: Как изменяется абсолютное расстояние между объектами выборки при изменении метрики минковского с $p=1$ до $p=\infty$?
#
# Изменится, т.к. $$\rho_{p=1}(x, y) = \sum\limits_{i=1}^{n}|x_i - y_i|$$,
# $$\rho_{p=\infty}(x,y) = \max_{i=1,...n}|x_i-y_i|$$
# Пусть максимум достигается в j-ой координате, тогда
# $$\rho_{p=1}(x,y) = |x_j-y_j| + \sum\limits_{i\neq j}|x_i - y_i| = \rho_{p=\infty}(x,y) + \sum\limits_{i\neq j}|x_i - y_i|$$
#
# **Вопрос 3**: Поясните, в чем суть проклятия размерности?
#
# При больших размерностях объекты становятся сильно удалены друг от друга (kNN неэффективен)
#
# ** Вопрос 4**: Что такое метрический отступ?
# Это "мера типичности" объекта. отрицателен тогда
# и только тогда, когда алгоритм допускает ошибку на данном объекте.
#
#
# ** Вопрос 5**: На какие типы можно разделить объекты обучающей выборки с точки зрения значения значения метрического отступа?
# Какие объекты стоит исключить из выборки?
#
# Эталоны, нормальные, пограничные, ошибки и выбросы.
# Можно сразу поудалять выбросы, но с небольшой вероятностью это может быть ошибочно, ибо они могут возникнуть из-за неправильного формирования выборки или метрики.
#
# **Вопрос 6**:  Что такое функционал эмпирического риска? Приведите примеры.
#
# Усреднение значений функции потерь.
#
# **Вопрос 7**:  В чём суть явления переобучения?
#
# Когда качество работы алгоритма на новых объектах, не вошедших в состав
# обучения, оказывается существенно хуже, чем на обучающей выборке, говорят об эф-
# фекте переобучения
#
# **Вопрос 8**: Напишите формулу для complete cross-validation.
#
# $$CV(\mu,X^L)=\frac1N \sum_{n=1}^N Q (\mu(X^m_n), X^k_n)$$
#
# Общий случай при $k>2$. Здесь число разбиений $N=C_L^k$ становится слишком большим даже при сравнительно малых значениях k, что затрудняет практическое применение данного метода. Для этого случая полный скользящий контроль используется либо в теоретических исследованиях, либо в тех редких ситуациях, когда для него удаётся вывести эффективную вычислительную формулу. Например, такая формула известна для метода k ближайших соседей, что позволяет эффективно выбирать параметр k.
#
# $$C^{lk}(\mu,X^L) = \sum\limits_{m=1}^{k}K(m, X^L)\frac{C^{l-1}_{L-1-m}}{C^l_{L-1}}$$
# Обозначим через $r_m(x_i)$ ошибку, возникающую, если правильный ответ y(x_i) на объекте x_i заменить ответом на его m-ом соседе
# $$K(m, X^L) = \frac{1}{L}\sum\limits_{i=1}^{L}r_m(x_i)$$
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.
#
# PPS: Стараюсь

# %% [markdown]
# <h1 align="center">Задача 1 (0.5 балла) </h1>

# %% [markdown]
# При каких значения параметра $k$ (при близких к единице или при сильно больших единицы) в алгоритме kNN можно наблюдать эффект переобучения? Поясните свой ответ, опираясь на границы классов из sklearn-knn-surfaces.ipynb.
#
# Рассмотрим условия достаточно большой выборки.
#
# Случай k близкий к единице приводит к переобучению, т.к. он берет одного, двух соседей и "голосование" становится слишком примитивным. К тому же эти парочка соседей могут быть просто "шумами".
#
# Случай очень большого k так же чреват переобучением, т.к. мы можем заметать классы, имеющие не так много объектов.

# %% [markdown]
# <h2 align="center">Реализуйте kNN (2 балла)</h2>

# %%
import warnings
import numpy as np
from scipy.spatial import distance
from collections import Counter

warnings.simplefilter("ignore")


class kNNClassifier():
    def __init__(self, n_estimators, metric):
        """
        Parameters
        ----------
        n_neighbours: int
            Число соседей

        metric: *alias
            метрика измерения расстояний

          """
        self.n_neighbours = n_estimators
        self.metric = metric
        
        
    def fit(self, X, y):
        """
        
        Parameters
        ----------
        X: 2d np.array
        y: 1d np.array
        """

        # Тут храните описание объектов обучающей выборки
        self.X_learn = X

        # Тут храните ответы по каждому объекту обучающей выборки
        self.y_learn = y

        
        return self

    def predict(self, X):
        """

        Parameters
        ----------
        X: 2d np.array матрица объекты признаки на которых нужно сказать ответ

        Returns
        -------
        y_pred: 1d np.array, Вектор классов для каждого объекта
        """
        dist = [] # Храните тут расстояния до каждого элемента обучающей выборки 
        
        for obj in X:
            plus_dim = []
            plus_dim.append(obj)
            #расстояние от каждого X до каждого тренировочного объекта
            dist.append(distance.cdist(self.X_learn, plus_dim, self.metric)) 
        
        pretend = []
        #для каждого X выявляем "ближайшие классы"
        for i in dist:
            pretend.append(self.y_learn[np.argsort(i, axis=0)[:self.n_neighbours]])
        #процесс голосования
        y_pred = [Counter(pretend[i][0]).most_common()[0][0] for i in range(len(pretend))]
        #P.S.: немного накостылил с индексами;( но вроде все работает хорошо
        
        return y_pred

# %%
# Запустите ваш алгоритм на данных Digit_recognizer
import pandas as pd

train = pd.read_csv('train.csv')

indices = list(range(train.shape[0]))
np.random.shuffle(indices)

subtrain, subtest = train.ix[indices[:5000]], train.ix[indices[5000:10000]]

X_train, X_test= np.asarray(subtrain[list(range(1, train.shape[1]))]), np.asarray(subtest[list(range(1, train.shape[1]))])
Y_train, Y_test = np.asarray(subtrain[[0]]).ravel(), np.asarray(subtest[[0]]).ravel()

# %%
from sklearn.metrics import accuracy_score
# =======================================
# Обучите классификатор при k=3, 5, и 10
# =======================================
clf = kNNClassifier(3, 'cityblock')
clf.fit(X_train,Y_train)
print accuracy_score(clf.predict(X_train), Y_train), accuracy_score(clf.predict(X_test), Y_test)
# Out:
# 1.0 0.9286

# %%
from sklearn.metrics import accuracy_score
# =======================================
# Обучите классификатор при k=3, 5, и 10
# =======================================
clf = kNNClassifier(5, 'euclidean')
clf.fit(X_train,Y_train)
print accuracy_score(clf.predict(X_train), Y_train), accuracy_score(clf.predict(X_test), Y_test)
# Out:
# 1.0 0.9374

# %%
from sklearn.metrics import accuracy_score
# =======================================
# Обучите классификатор при k=3, 5, и 10
# =======================================
clf = kNNClassifier(10, 'cosine')
clf.fit(X_train,Y_train)
print accuracy_score(clf.predict(X_train), Y_train), accuracy_score(clf.predict(X_test), Y_test)
# Out:
# 1.0 0.9468

# %% [markdown]
# <h1 align="center">Кросс-валидация (2 балла) </h1>

# %% [markdown]
# <h2 align="left">Зависимость значения CV от размера тестовой выборки </h2>
#
# Продемонстрируйте экспериментально, как меняется значения $CV$ в зависимости от $k$ - количество объектов в тестовой выборке, если объём всех данных меняется и равен $l+k$ (т.е. количество объектов в обучающей выборке НЕ меняется).
#
# Размер обучающей выборки $l$ взять таким, чтобы можно было значения CV при $k=10\cdot l$.
# Демонстрацию провести на данных из соревнования <a href="http://www.kaggle.com/c/digit-recognizer">Digit Recognizer</a> на
# Kaggle.
#
# В качестве алгоритма классификации можно взять
# <span style="color:black; font-size: 14pt">sklearn.neighbors.KNeighborsClassifier(algorithm='ball\_tree')</span>.

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

l = 3000
for i in range(1,11):
    k=i*l
    subtrain, subtest = train.ix[indices[:l]], train.ix[indices[l:l+k]]
    X_train, X_test= np.asarray(subtrain[list(range(1, train.shape[1]))]), np.asarray(subtest[list(range(1, train.shape[1]))])
    Y_train, Y_test = np.asarray(subtrain[[0]]).ravel(), np.asarray(subtest[[0]]).ravel()
    
    clf = KNeighborsClassifier(algorithm='ball_tree')
    clf.fit(X_train, Y_train)
    
    print cross_val_score(clf, X_test, Y_test, cv=5)
# Out:
# [ 0.92384106  0.92026578  0.9048414   0.92474916  0.91289782]
# [ 0.93521595  0.94171524  0.94578816  0.93744787  0.94152047]
# [ 0.9434903   0.94780677  0.95055556  0.94602115  0.94156928]
# [ 0.95049917  0.95047857  0.9516868   0.94826867  0.94488518]
# [ 0.95840266  0.96037296  0.94998333  0.94929953  0.95258765]
# [ 0.96086595  0.96029983  0.95140239  0.95748819  0.95354659]
# [ 0.96336822  0.9605044   0.95858129  0.95640781  0.95517406]
# [ 0.96544546  0.96023319  0.96000833  0.95955806  0.95745568]
# [ 0.96687026  0.96168086  0.96352527  0.9581404   0.9592215 ]
# [ 0.96818787  0.96334555  0.96333333  0.95965322  0.95880587]

# %% [markdown]
# При увеличение тестовых данных уменьшается процентное соотношение шумов => модель показывает большую степень пригодности. + похоже модель хорошо обучилась на этих l объектах.

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

l = 300
for i in range(1,11):
    k=i*l
    subtrain, subtest = train.ix[indices[:l]], train.ix[indices[l:l+k]]
    X_train, X_test= np.asarray(subtrain[list(range(1, train.shape[1]))]), np.asarray(subtest[list(range(1, train.shape[1]))])
    Y_train, Y_test = np.asarray(subtrain[[0]]).ravel(), np.asarray(subtest[[0]]).ravel()
    
    clf = KNeighborsClassifier(algorithm='ball_tree')
    clf.fit(X_train, Y_train)
    
    print cross_val_score(clf, X_test, Y_test, cv=5)
# Out:
# [ 0.77777778  0.77419355  0.65        0.77586207  0.80701754]
# [ 0.816       0.81147541  0.85833333  0.80508475  0.8173913 ]
# [ 0.85326087  0.84699454  0.84357542  0.83615819  0.84745763]
# [ 0.87295082  0.88016529  0.87136929  0.85232068  0.88983051]
# [ 0.875       0.91089109  0.87959866  0.89597315  0.86148649]
# [ 0.87945205  0.88950276  0.90529248  0.90782123  0.87359551]
# [ 0.88941176  0.9028436   0.91428571  0.882494    0.89903846]
# [ 0.9068323   0.90871369  0.89561587  0.89979123  0.92872117]
# [ 0.90257353  0.90942699  0.9037037   0.90723562  0.91231343]
# [ 0.91404959  0.91181364  0.89816361  0.92320534  0.90100671]

# %% [markdown]
# <h1 align="center">Bonus part</h1>

# %% [markdown]
# Это удвоит баллы за дз.
#
# - Резберитесь с расчётом Margin, приведённом в семинарском занятии. Воспроизведите раздел Off-line contest и подберите метрику, для которой линия Margin-ов была бы не меньше, чем для метрики cosine.

# %%
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier
from sklearn.neighbors.base import _get_weights

estimator = NearestNeighbors()
estimator.fit(X_train)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
def calculate_weighted_margin(estimator, class_id, example, Y_train=Y_train, debug=False):
    """
    We assume that we have distance weights. We also assume
    that we fit our estimator on the whole set. It means
    that we already have our example inside estimator. That is
    why, the first nearest neighbor would be example object.
    
    @param estimator: KNeighborsMixin sublcassed object
        should be already fitted.
    @param class_id: example object has class class_id
    @param example: numpy.array feature represenation of
        example (1x784 matrix based on 28x28 reshaping)
    @param Y_train: we should know object class by its index id
   
    """
    distances, indices = estimator.kneighbors([example])
    weights = _get_weights(np.asarray([distances[0][1:]]), 'distance')[0]
    if weights.sum()>0:
        weights /= weights.sum()     # деление на ноль
    classes = Y_train[indices[0][1:]]
    
    counts = Counter()
    for class_id_, weight in zip(classes, weights):
        counts[class_id_] += weight
    if debug:
        # in production environment we should use logging module!
        print (counts)
    margin = counts[class_id]
    del counts[class_id]
    if counts:
        margin -= max(counts.values())
    return margin

# %%
def collect_margins(n_neighbors, margin_calculator, X_train=X_train, Y_train=Y_train, debug_example_id = None, **kwargs):
    margins = []
    estimator = NearestNeighbors(n_neighbors=n_neighbors + 1, **kwargs)
    estimator.fit(X_train)
    for example_id, (class_id, example) in enumerate(zip(Y_train, X_train)):
        margin = margin_calculator(estimator, class_id, example, debug=(example_id == debug_example_id))
        margins.append(margin)

    return margins

# %%
def metric_correlation(x,y):
    u = x - np.mean(x)
    v = y - np.mean(y)
    return 1 - np.dot(u,v)/(np.sqrt(np.dot(v,v)*np.dot(u,u)))

def metric_cos(x,y):
    return 1 - np.dot(x,y)/(np.sqrt(np.dot(x,x)*np.dot(y,y)))


metric_properties = {
#    'euc' : {'metric' : 'euclidean'}, # 
    'cosine' : {'metric' : metric_cos},    
    'correlation' : {'metric' : metric_correlation}
}

# %%
metric_margins = {}
for name, metric in metric_properties.items():
    margins = collect_margins(n_neighbors=5, margin_calculator=calculate_weighted_margin, **metric)
    metric_margins[name] = sorted(margins)

# %%
import pandas as pd
# %matplotlib
team_df = pd.DataFrame(metric_margins)
team_df.plot(figsize = (15, 10))
# Out:
# Using matplotlib backend: TkAgg

# %%
from IPython.display import Image
Image('figure_1.png')
